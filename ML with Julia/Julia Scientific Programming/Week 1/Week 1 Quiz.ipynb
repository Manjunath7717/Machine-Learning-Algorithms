# %% [markdown]
# # Week 1 Quiz

# %% [markdown]
# <h2 id="int"> Question 1      </h2>
#
# Which of the following expressions will evaluate to the number (integer) 12? Check all that are correct. There are more than one correct answer.
#
# Recall that Julia evaluates arithmetic operators in the following order: Exponential ^, multiplication * and division / are executed first followed by addition + and subtraction -.
#
#
# a. 2^2^1^5+2^3
#
#
# b. println("$(2*6)")
#
#
# c. (2^3)^2-500
#
#
# d. 2^3^2-500

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# 2^2^1^5+2^3
# 12
# println("$(2*6)")
# 12
# 2^3^2-500
# 12
#
# Answer: a,b,d
# -->

# %% [markdown]
# <h2 id="int"> Question 2     </h2>
#
# In Julia the following expression evaluates to -5:
#
# 5 - 7 * 2 + 4
#
# Rewrite this, without changing the numbers, their order, or the operators, but inserting one pair of parentheses, so that it evaluates to 0
#
#
#
# a.5-7*(2+4)
#
# b. (5-7)*2+4
#
# c. 5-(7*2)+4

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# 5 - 7 * (2 + 4)
# -37
# (5-7)*2+4
# 0
# 5-(7*2)+4
# -5
#
# Answer: b
# -->

# %% [markdown]
# <h2 id="int"> Question 3      </h2>
#
# What is the result of evaluating of the following Julia expression?
#
# 1 + 3 < 5 && 2^2 === 4.0
#
#
#
# a. MethodError
#
# b. true
#
# c. false

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# 1 + 3 < 5 && 2^2 === 4.0
# false
# Answer: C
# -->

# %% [markdown]
# <h2 id="int"> Question 4      </h2>
#
# Suppose we write the following logical expression in Julia:
#
# (x ≥ 5.0) && (x < 7.0)
#
# If x is a numeric variable of type Float or Integer, then which one of the following statements is true?
# 1 point
#
#
# a. This is an invalid Julia expression
#
# b. The expression evaluates to true for x equal to 5 and 6, but no other integer values.
#
# c. The expression evaluates to true for all real numbers x in the closed interval from 5 to 7. Julia represents real numbers using the Float type.

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# (7 ≥ 5.0) && (7 < 7.0)
# false
# Answer: B
# -->

# %% [markdown]
# <h2 id="int"> Question 5      </h2>
#
# Add two pairs of parentheses "(..)" to the expression below so that it is unambiguous in how Julia evaluates the expression to true:
#
# true && false && false || true
#
# Select all the equivalent expressions below that satisfy this requirement. There may be more than one correct answer, so select all correct answers
#
#
#
# a.(true && false) && (false || true)
#
# b. true && (false && (false || true))
#
# c. ((true && false) && false) || true
#
# d. true && ((false && false) || true)

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# true && false && false || true
# true
# (true && false) && (false || true)
# false
# true && (false && (false || true))
# false
# ((true && false) && false) || true
# true
# true && ((false && false) || true)
# true
# Answer: C and D
# -->

# %% [markdown]
# <h2 id="int"> Question 6      </h2>
#
# If a and b are assigned positive integers values, then how many rows and columns does 'matrix' have if it is defined as follows:
#
# matrix = Array{Float64,2}(undef, a, b)
#
#
#
# a.64 rows and 2 columns
#
# b. a rows and b columns
#
# c. undef
#
# d. a columns and b rows

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# matrix = Array{Float64,2}(undef, a, b)
# undef
# Answer: C
# -->

# %% [markdown]
# <h2 id="int"> Question 7      </h2>
#
# Which line of code returns the first column, representing all the  x-values, in the array called data that is use to store
# x-value and y-value pairs. The array is defined as follows:
#
#
# data = [1.6800483  -1.641695388;
#
#         0.501309281 -0.977697538;
#
#         1.528012113 0.52771122;
#
#         1.70012253 1.711524991;
#
#         1.992493625 1.891000015;
#
#         2.706075824 -0.463427794;
#
#         2.994931927 -0.443566619;
#
#         3.491852811 -1.275179133;
#
#         3.501191722 -0.690499597;
#
#         4.459924502 -5.516130799;
#
#         4.936965851 -6.001703074;
#
#         5.023289852 -8.36416901;
#
#         5.04233698 -7.924477517;
#
#         5.50739285 -10.77482371;
#
#         5.568665171 -10.9171878]
#
#
#
# a. data[1,:]
#
# b. data[:,1]
#
# c. data[:,0]
#
# d. data[2,:]

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# data = [1.6800483  -1.641695388;
#         0.501309281 -0.977697538;
#         1.528012113 0.52771122;
#         1.70012253 1.711524991;
#         1.992493625 1.891000015;
#         2.706075824 -0.463427794;
#         2.994931927 -0.443566619;
#         3.491852811 -1.275179133;
#         3.501191722 -0.690499597;
#         4.459924502 -5.516130799;
#         4.936965851 -6.001703074;
#         5.023289852 -8.36416901;
#         5.04233698 -7.924477517;
#         5.50739285 -10.77482371;
#         5.568665171 -10.9171878]
#
# data[1,:]
# 2-element Array{Float64,1}:
#   1.6800483
#  -1.641695388
#
# Answer: A
# -->

# %% [markdown]
# <h2 id="int"> Question 8      </h2>
#
# The following Julia function prints the x y and z values only if they are not all equal to zero. If these value are all zero then it prints word "origin".
#
# function coordinates(x, y, z)
#
#   if # select appropriate condition from list below so this code works
#
#     println("origin")
#
#   else
#
#     println("($x, $y, $z)")
#
#   end
#
# end
#
# For example the function should, given these inputs, produce the expected outputs:
#
#
# coordinates(0,0,2) must print:
# (0,0,2)
#
# coordinates(0,0,0) must print:
# origin
#
# Which of the following if statements will ensure this function produces the correct output. There are more than one correct answers. Select all that are correct.
#
#
#
# a. if x==0 && y==0 && x==z
#
# b. if x=0 & y=0 & z=0
#
# c. if x===0.0 && y===0.0 && z===0.0
#
# d. if x==0 & y==0 & z==0
#
# e. if x==0 && z==0 && y==0

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# function coordinates(x, y, z)
#      if x==0 && y==0 && x==z
#      println("origin")
#     else
#      println("($x, $y, $z)")
#     end
# end
# coordinates(0,0,0)
# origin
# Answer: A, D and E
# -->

# %% [markdown]
# <h2 id="int"> Question 9      </h2>
#
# If you enter the following code in Jupyter Notebook cell
#
# a, b = 2, 3
#
# function f(x)
#
#   b = 5
#
#   a*x + b
#
# end
#
# f(7), b
# the output is (19, 3), which means that the function returned the value 19 and the value of b at the end of the cell is 3.
#
# Which one of the following explanations for this behavior is correct?
#
#
#
# a. Inside the function f, b is set to a new value 5, while a is 2 and x is 7. The function f returns a*x+b which is 19. But this does not change b outside the function, so the value of b reported at the end is still 3.
#
# b. There is a bug in the code which causes the wrong value of b to be used in the function.
#
# c. The function sets b to 5. But then it sets b to 3 before it ends.
#
# d. The variable a is 2 and b is 3 at the start. The output is a tuple of the values of f(7) and of b. Here, f(7) the value of a*x+b for x = 7, a = 2 and b = 3 as assigned in the first line.

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# a, b = 2, 3
#
# function f(x)
#
#   b = 5
#
#   a*x + b
#
# end
#
# f(7), b
# (19, 3)
# Answer: A
# -->

# %% [markdown]
# <h2 id="int"> Question 10      </h2>
#
# Suppose the function f is defined as follows:
#
# function f(x)
#
#   return 2x
#
#   3x
#
# end
#
# What is the value of f(5), and why?
#
# The function throws an error, because 2x should be 2*x.
#
#
# a. f(5) returns 10. The 'return' statement means the function stops execution after calculating and returning the value 2x.
#
#
# b. f(5) returns 15. The last line is 3x, which is equivalent to 3*x.
#
#
# c. f(5) = 10. The function calculates both 2*x and 3*x but returns only the one that follows the keyword "return".

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# function f(x)
#
#   return 2x
#
#   3x
#
# end
# f(5)
# 10
# Answer: C
# -->
